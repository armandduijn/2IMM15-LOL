# %%
import logging
import pyLDAvis.gensim
import json
import gensim

# %%
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logging.debug("test")
# Out:
# DEBUG:root:test

# %%
dictionary = gensim.corpora.Dictionary.load('alltoken.dict')
corpus = gensim.corpora.MmCorpus('corpus.mm')
lda = gensim.models.LdaModel.load('lda_topic8.lda')
# lda = gensim.models.LdaModel(corpus=corpus, id2word=dictionary, iterations=100, num_topics=8)
# Out:
# INFO:gensim.utils:loading Dictionary object from alltoken.dict
# INFO:gensim.utils:loaded alltoken.dict
# INFO:gensim.corpora.indexedcorpus:loaded corpus index from corpus.mm.index
# INFO:gensim.matutils:initializing corpus reader from corpus.mm
# INFO:gensim.matutils:accepted corpus with 6560 documents, 22889 features, 416606 non-zero entries
# INFO:gensim.utils:loading LdaModel object from lda_topic8.lda
# INFO:gensim.utils:loading expElogbeta from lda_topic8.lda.expElogbeta.npy with mmap=None
# INFO:gensim.utils:setting ignored attribute id2word to None
# INFO:gensim.utils:setting ignored attribute state to None
# INFO:gensim.utils:setting ignored attribute dispatcher to None
# INFO:gensim.utils:loaded lda_topic8.lda
# INFO:gensim.utils:loading LdaModel object from lda_topic8.lda.state
# INFO:gensim.utils:loaded lda_topic8.lda.state

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# Out:
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 6560 documents
# DEBUG:gensim.models.ldamodel:6560/6560 documents converged within 500 iterations
# d:\python\lib\site-packages\pyLDAvis\_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]

# %%
pyLDAvis.save_html(vis ,'./pyldavis/topic_t+t+a_8.html')

# %%
pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# Out:
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 6560 documents
# DEBUG:gensim.models.ldamodel:6560/6560 documents converged within 500 iterations
# d:\python\lib\site-packages\pyLDAvis\_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 5      42.390487        1       1  0.138675 -0.058535
# 2      35.456947        1       2  0.134844  0.063540
# 0       5.306649        1       3 -0.016540 -0.021780
# 6       4.007176        1       4 -0.038493  0.008837
# 1       3.947496        1       5 -0.040005  0.009776
# 4       3.572482        1       6 -0.026380  0.000286
# 7       3.061876        1       7 -0.055409 -0.006722
# ...
