# %%
import gensim
from gensim.models.wrappers.dtmmodel import DtmModel
from gensim.corpora import Dictionary, bleicorpus
import pyLDAvis
corpus = gensim.corpora.MmCorpus('../topic_modeling/topics/corpus.mm')
ldaseq = gensim.models.ldaseqmodel.LdaSeqModel.load('ldaseq')

# %%
doc_topic, topic_term, doc_lengths, term_frequency, vocab = ldaseq.dtm_vis(time=1, corpus=corpus)
vis_dtm = pyLDAvis.prepare(topic_term_dists=topic_term, doc_topic_dists=doc_topic, doc_lengths=doc_lengths, vocab=vocab, term_frequency=term_frequency)
pyLDAvis.display(vis_dtm)
# Out:
# d:\python\lib\site-packages\pyLDAvis\_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el74121952879449125237867"></div>
# <script type="text/javascript">
#
# ...

# %%
pyLDAvis.save_htlm(vis_dtm, './dtmvis/8topicsevolution.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-bbf9fc8962ae> in <module>()
# ----> 1 pyLDAvis.save_htlm(vis_dtm, './dtmvis/8topicsevolution.html')
#
# AttributeError: 'module' object has no attribute 'save_htlm'
